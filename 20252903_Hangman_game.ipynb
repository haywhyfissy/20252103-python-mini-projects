# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
#from data_cleaning import clean_missing_values
#from data_cleaning import clean_outliers
import data_cleaning

# %%
df = pd.read_csv("C:/Users/haywh/Desktop/unisalento/Phd courses/Data Analysis/PugliaAirQualityYear2023.csv")
df.head(10)
# Out:
#   measurement_date   station_id                      name  municipality  \
# 0       2023-01-01           64  Altamura - Via Santeramo      Altamura
# 1       2023-01-01           64  Altamura - Via Santeramo      Altamura
# 2       2023-01-01           64  Altamura - Via Santeramo      Altamura
# 3       2023-01-01           64  Altamura - Via Santeramo      Altamura
# 4       2023-01-01           17          Bari - Caldarola          Bari
# 5       2023-01-01           17          Bari - Caldarola          Bari
# 6       2023-01-01           17          Bari - Caldarola          Bari
# 7       2023-01-01           17          Bari - Caldarola          Bari
# 8       2023-01-01           17          Bari - Caldarola          Bari
# 9       2023-01-01           81          Bari - Carbonara          Bari
#
#    province   longitude   latitude  area_type  station_type  network  \
# 0      Bari   16.561015  40.828848   Suburban          Soil     RRQA
# ...

# %%
df.isna().sum()
# Out:
# measurement_date                 0
#  station_id                      0
#  name                            0
#  municipality                    0
#  province                        0
#  longitude                       0
#  latitude                        0
#  area_type                   58765
#  station_type                58765
#  network                         0
#  network_interest                0
#  measured_pollutant              0
#  measured_pollutant_value    27827
#  limit                       13140
#  measurement_unit                0
#  exceedances                  7300
#  quality_index               51504
#  quality_class               51504
# dtype: int64

# %%
num_col = []
cat_col = df.columns.values.tolist()
data_cleaning.clean_missing_values(df, num_col, cat_col)
# Out:
# Data cleaning completed.
# Dataframe shape after cleaning: (258055, 18)
#  Dataframe shape before cleaning: (258055, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258055 entries, 0 to 258054
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   measurement_date           258055 non-null  object
#  1    station_id                258055 non-null  float64
#  2    name                      258055 non-null  object
#  3    municipality              258055 non-null  object
#  4    province                  258055 non-null  object
#  5    longitude                 258055 non-null  float64
#  6    latitude                  258055 non-null  float64
#  7    area_type                 258055 non-null  object
#  8    station_type              258055 non-null  object
#  9    network                   258055 non-null  object
#  10   network_interest          258055 non-null  object
# ...
